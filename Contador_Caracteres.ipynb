# %% [markdown]
# ## Contador de Caracteres

# %%
def contador_caracteres(x):
    contador = {}
    for i in x:
        if i in contador:
            contador[i] += 1
        else:
            contador[i] = 1
    print(contador)
palabra = input("Ingrese una palabra:")
print(contador_caracteres(palabra))
# Out:
# {'H': 1, 'o': 3, 'l': 1, 'a': 2, ' ': 2, 'c': 1, 'm': 1, 'e': 1, 's': 2, 't': 1}
# None
